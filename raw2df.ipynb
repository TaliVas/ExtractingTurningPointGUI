# %%
import scipy.io
import os
import pandas as pd
import numpy as np

# Define the folders
day_dir = '/Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222'
csv_dir = os.path.join(day_dir, 'DLC_color')
Info_dir = os.path.join(day_dir, 'Info')
EDfiles_dir = os.path.join(day_dir, 'EDfiles')
ED2videomap_dir = os.path.join(day_dir, 'ED2videomap')

def extract_data_from_info(): #info of entire day
    Info_file = [f for f in os.listdir(Info_dir) if f.endswith('param.mat')][0]
    Info_file_path = os.path.join(Info_dir , Info_file)
    Info_data = scipy.io.loadmat(Info_file_path)
    recording_day_id = Info_data['DDFparam']['ID'][0][0][0][0]
    SESSparam = Info_data['SESSparam']
    fileConfig = SESSparam['fileConfig'][0, 0]
    HFS_field = fileConfig['HFS'][0]
    type_list = np.array([int(x[0][0]) for x in HFS_field])
    SubSess = SESSparam['SubSess'][0, 0]
    Files_field = SubSess['Files'][0][0]
    session_list = Files_field.tolist()

    return recording_day_id, type_list, session_list

def extract_data_from_edfiles_ed2videomap(recording_day_id, type_list, session_list):
    temp = [] # Empty list for dataframes

    # Loop through all MAT files in the folder
    for i, file_name in enumerate(os.listdir(EDfiles_dir)):
        ed_file_path = os.path.join(EDfiles_dir, file_name)
        map_file_path = os.path.join(ED2videomap_dir, file_name)
        file_index = os.path.splitext(file_name)[0].split('.')[-1]
        
        # Load the ED file
        ed_data = scipy.io.loadmat(ed_file_path)
        failed_non_failed = ed_data['trials'][:, 2]
        trial_events = ed_data['TrialTimes']
        id_target = ed_data['bhvStat'][:, 2]
        id_update = ed_data['bhvStat'][:, 3]
        
        # Load the map file
        ED2videomap = scipy.io.loadmat(map_file_path)['ed2video']

        # Extract the relevant columns
        df = pd.DataFrame(np.round(ED2videomap), columns=['trial_number_in_file', 'DLC_color_id'])
        df['failed_non_failed'] = failed_non_failed
        df_non_failed = df[df['failed_non_failed'] == 1].copy()
        df_non_failed['file_number'] = int(file_index)
        df_non_failed['recording_day'] = recording_day_id
        df_non_failed['type'] = df_non_failed['file_number'].apply(lambda idx: 'HFS' if type_list[int(idx)-1] == 1 else 'Control')
        for session_number, (start, end) in enumerate(session_list, start=1):
            if start <= int(file_index) <= end:
                df_non_failed['session_number'] = session_number
                break

        df_non_failed['start_time'] = trial_events[:, 0]
        df_non_failed['end_time'] = trial_events[:, 10]
        df_non_failed['que_time'] = trial_events[:, 3]
        df_non_failed['go_time'] = trial_events[:, 4]
        df_non_failed['update_time'] = trial_events[:, 5]
        df_non_failed['move_time'] = trial_events[:, 6]
        df_non_failed['id_target'] = id_target
        df_non_failed['id_update'] = id_update
        temp.append(df_non_failed)
    # Concatenate all DataFrames into one    
    final_df = pd.concat(temp, ignore_index=True)
    # Sort the DataFrame by 'file_number' and then by 'trial_number'
    final_df_sorted = final_df.sort_values(by=['file_number','trial_number_in_file'], ascending=[True,True])
    final_df_sorted = final_df_sorted.reset_index(drop=True)
    final_df_sorted.dropna(subset=['DLC_color_id'], inplace=True)
    final_df_sorted['DLC_color_id'] = final_df_sorted['DLC_color_id'].astype(int)
    final_df_sorted['trial_number_in_file'] = final_df_sorted['trial_number_in_file'].astype(int)
    final_df_sorted['file_number'] = final_df_sorted['file_number'].astype(int)
    final_df_sorted['id_target'] = final_df_sorted['id_target'].astype(int)

    return final_df_sorted

def extract_data_from_csv(final_df_sorted):
    dfs = []
    indices = final_df_sorted['DLC_color_id'].astype(int)
    for index in indices:
        pattern = "trial" + str(index) + "-"
        for i, file_name in enumerate(os.listdir(csv_dir)):
            if pattern in file_name:
                csv_file_path = os.path.join(csv_dir, file_name)
                headers = pd.read_csv(csv_file_path, nrows=3)
                combined_header = ['_'.join(col) for col in zip(headers.iloc[0], headers.iloc[1])]
                df = pd.read_csv(csv_file_path, skiprows=3, names=combined_header)
                # Calculate the median for the relevant 'x' and 'y' columns
                x_columns = ['tip2_x', 'tip3_x', 'tip4_x', 'tip5_x']
                x_median = np.median(df[x_columns], axis=1)
                y_columns = ['tip2_y', 'tip3_y', 'tip4_y', 'tip5_y']
                y_median = np.median(df[y_columns], axis=1)
                # Create a new DataFrame with 'id', 'x_median', and 'y_median'
                temp_df = pd.DataFrame({'DLC_color_id': index, 'x': x_median,'y': y_median})
                # Append the DataFrame to the list
                dfs.append(temp_df)
    coord_df = pd.concat(dfs, ignore_index=True)

    return coord_df

def merge_events_coordinates(final_df_sorted, coord_df):
    merged_df = final_df_sorted.merge(coord_df, on='DLC_color_id', how='left')
    merged_df.drop(columns=['failed_non_failed'], inplace=True)
    return merged_df

# %%
recording_day_id, type_list, session_list = extract_data_from_info()
events_df_sorted = extract_data_from_edfiles_ed2videomap(recording_day_id, type_list, session_list)
coord_df = extract_data_from_csv(events_df_sorted)
merged_df = merge_events_coordinates(events_df_sorted, coord_df)

# %%
# Out:
#         DLC_color_id           x           y  trial_number_in_file  \
# 0                  1    5.085012    1.148422                     1
# 1                  1    5.799622    1.531673                     1
# 2                  1  163.021950    2.770684                     1
# 3                  1  162.626259    2.479106                     1
# 4                  1  162.626259    2.273755                     1
# ...              ...         ...         ...                   ...
# 263963          1341  563.167084  165.665161                   121
# 263964          1341  563.153900  166.022758                   121
# 263965          1341  563.391266  166.023102                   121
# 263966          1341  562.923828  166.023102                   121
# 263967          1341  562.473267  166.023102                   121
#
#         file_number  recording_day     type  session_number  start_time  \
# 0                 1             32  Control               1     67.1168
# 1                 1             32  Control               1     67.1168
# 2                 1             32  Control               1     67.1168
# 3                 1             32  Control               1     67.1168
# 4                 1             32  Control               1     67.1168
# ...             ...            ...      ...             ...         ...
# 263963           15             32  Control               1    442.3766
# 263964           15             32  Control               1    442.3766
# 263965           15             32  Control               1    442.3766
# 263966           15             32  Control               1    442.3766
# 263967           15             32  Control               1    442.3766
#
#           end_time    que_time   go_time  update_time   move_time  id_target  \
# 0        72.226233   68.323667   68.6578          NaN   68.809167          4
# 1        72.226233   68.323667   68.6578          NaN   68.809167          4
# 2        72.226233   68.323667   68.6578          NaN   68.809167          4
# 3        72.226233   68.323667   68.6578          NaN   68.809167          4
# 4        72.226233   68.323667   68.6578          NaN   68.809167          4
# ...            ...         ...       ...          ...         ...        ...
# 263963  443.881933  442.940533  443.2911          NaN  443.358233          4
# 263964  443.881933  442.940533  443.2911          NaN  443.358233          4
# 263965  443.881933  442.940533  443.2911          NaN  443.358233          4
# 263966  443.881933  442.940533  443.2911          NaN  443.358233          4
# 263967  443.881933  442.940533  443.2911          NaN  443.358233          4
#
#         id_update
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 263963        NaN
# 263964        NaN
# 263965        NaN
# 263966        NaN
# 263967        NaN
#
# [263968 rows x 16 columns]

# %%
import os
import pandas as pd
import numpy as np

# Define the folder containing your CSV files
csv_dir = '/Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color'

# Initialize an empty list to hold DataFrames
dfs = []

# Loop through all CSV files in the folder
for i, file_name in enumerate(os.listdir(csv_dir)):
    # Construct full file path
    file_path = os.path.join(csv_dir, file_name)
    # Load the CSV, skipping the first row and reading the next two rows as the header
    headers = pd.read_csv(file_path, nrows=3)
    # Combine the two rows to form a single header
    combined_header = ['_'.join(col) for col in zip(headers.iloc[0], headers.iloc[1])]
    # Load the data, skipping the first three rows, and use the unique header
    df = pd.read_csv(file_path, skiprows=3, names=combined_header)
    # Calculate the median for the relevant 'x' and 'y' columns
    x_columns = ['tip2_x', 'tip3_x', 'tip4_x', 'tip5_x']
    x_median = np.median(df[x_columns], axis=1)
    y_columns = ['tip2_y', 'tip3_y', 'tip4_y', 'tip5_y']
    y_median = np.median(df[y_columns], axis=1)
    # Create a new DataFrame with 'id', 'x_median', and 'y_median'
    temp_df = pd.DataFrame({'id': i+1, 'x': x_median,'y': y_median})
    # Append the DataFrame to the list
    dfs.append(temp_df)

# Concatenate all DataFrames into one
coord_data = pd.concat(dfs, ignore_index=True)






def load_data_from_files(search_path:str, indices:list):
    for index in indices:
        pattern = "trial" + str(index) + "-"
        for root, dirs, files in os.walk(search_path):
            for file in files:
                if pattern in file:
            


load_data_from_files("/Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color", indices)
# Out:
# Found pattern 'trial1-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial1-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial2-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial2-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial3-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial3-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial4-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial4-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial5-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial5-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial6-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial6-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial8-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial8-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial9-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial9-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial10-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial10-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial11-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial11-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial12-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial12-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial13-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial13-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial15-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial15-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial16-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial16-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial17-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial17-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial18-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial18-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial19-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial19-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial20-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial20-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial21-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial21-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial22-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial22-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial23-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial23-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial25-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial25-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial26-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial26-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial27-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial27-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial28-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial28-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial29-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial29-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial30-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial30-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial31-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial31-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial32-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial32-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial33-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial33-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial34-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial34-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial36-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial36-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial37-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial37-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial38-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial38-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial39-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial39-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial40-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial40-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial45-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial45-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial46-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial46-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial47-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial47-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial48-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial48-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial49-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial49-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial50-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial50-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial51-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial51-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial52-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial52-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial54-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial54-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial55-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial55-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial56-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial56-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial57-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial57-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial58-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial58-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial59-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial59-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial60-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial60-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial61-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial61-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial62-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial62-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial63-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial63-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial64-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial64-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial65-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial65-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial66-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial66-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial67-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial67-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial68-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial68-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial69-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial69-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial70-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial70-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial71-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial71-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial73-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial73-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial74-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial74-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial75-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial75-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial76-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial76-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial77-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial77-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial78-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial78-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial79-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial79-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial80-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial80-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial81-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial81-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial82-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial82-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial83-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial83-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial84-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial84-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial88-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial88-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial89-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial89-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial90-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial90-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial91-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial91-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial92-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial92-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial93-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial93-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial94-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial94-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial95-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial95-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial96-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial96-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial97-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial97-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial98-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial98-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial99-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial99-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial100-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial100-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial102-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial102-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial103-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial103-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial104-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial104-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial105-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial105-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial106-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial106-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial107-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial107-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial108-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial108-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial109-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial109-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial111-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial111-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial112-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial112-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial113-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial113-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial114-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial114-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
# Found pattern 'trial115-' in file: /Users/avitalvasiliev/Documents/GitHub/ExtractingTurningPointGUI/t011222/DLC_color/tkhina-trial115-camera-6DLC_resnet152_t-rest-colorJul19shuffle1_750000_filtered.csv
